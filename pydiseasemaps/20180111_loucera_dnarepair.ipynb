# %%
import os
import libsbgnpy.libsbgn as libsbgn
from libsbgnpy.render import render_sbgn
from libsbgnpy.utils import print_bbox  # some additional helpers

# %%
def read_sbgn(f):
    """ Read example file and display content.

    :param f: SBGN file to read
    :return: sbgn
    """
    sbgn = libsbgn.parse(f)

    # map is a container for the glyphs and arcs
    smap = sbgn.get_map()

    # we can get a list of glyphs (nodes) in this map with getGlyph()
    for g in smap.get_glyph():
        # print the sbgn class of this glyph
        print(" Glyph with class", g.get_id())

        # if there is a label, print it as well
        if g.get_label():
            print(", and label ", g.get_label().get_text())
        else:
            print(", without label")

    # we can get a list of arcs (edges) in this map with getArc()
    for a in smap.get_arc():
        # print the class of this arc
        print(" Arc with class ", a.get_class())

    return sbgn

# %%
data_dirpath = os.path.join("..", "data", "dna_repair_map")
sbgn_filepath = os.path.abspath(os.path.join(data_dirpath, "dna.sbgn"))
print(sbgn_filepath)
# Out:
# /home/cloucera/projects/diseasemaps/data/dna_repair_map/dna.sbgn

# %%
sbgn = read_sbgn(sbgn_filepath)
# Out:
# <?xml version="1.0" ?>
# <sbgn:sbgn xmlns:sbgn="http://sbgn.org/libsbgn/0.2">
#     <sbgn:map xmlns:sbgn="http://sbgn.org/libsbgn/0.2" language="process description">
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re1">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2966.599999999999909" y="7373.600000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re1.L" x="2966.599999999999909" y="7378.600000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re1.R" x="2976.599999999999909" y="7378.600000000000364"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re2">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2413.199999999999818" y="7688."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re2.L" x="2413.199999999999818" y="7693."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re2.R" x="2423.199999999999818" y="7693."/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re3">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="1859.900000000000091" y="8041."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re3.L" x="1859.900000000000091" y="8046."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re3.R" x="1869.900000000000091" y="8046."/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re4">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2966.599999999999909" y="7659.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re4.L" x="2966.599999999999909" y="7664.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re4.R" x="2976.599999999999909" y="7664.699999999999818"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re5">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2965.599999999999909" y="7091.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re5.L" x="2965.599999999999909" y="7096.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re5.R" x="2975.599999999999909" y="7096.800000000000182"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re6">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="1867.900000000000091" y="7154.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re6.L" x="1867.900000000000091" y="7159.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re6.R" x="1877.900000000000091" y="7159.699999999999818"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re7">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="1859.900000000000091" y="7484.600000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re7.L" x="1859.900000000000091" y="7489.600000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re7.R" x="1869.900000000000091" y="7489.600000000000364"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re8">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2227." y="7729.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re8.L" x="2227." y="7734.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re8.R" x="2237." y="7734.399999999999636"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re9">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="1859.900000000000091" y="7736.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re9.L" x="1859.900000000000091" y="7741.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re9.R" x="1869.900000000000091" y="7741.800000000000182"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re10">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="3410.400000000000091" y="7708.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re10.L" x="3410.400000000000091" y="7713.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re10.R" x="3420.400000000000091" y="7713.399999999999636"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re11">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="2238.099999999999909" y="8412.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re11.L" x="2238.099999999999909" y="8417.399999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re11.R" x="2248.099999999999909" y="8417.399999999999636"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re12">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="1010.399999999999977" y="7519."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re12.L" x="1010.399999999999977" y="7524."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re12.R" x="1020.399999999999977" y="7524."/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re13">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="231.900000000000006" y="7142.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re13.L" x="231.900000000000006" y="7147.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re13.R" x="241.900000000000006" y="7147.699999999999818"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re14">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="469.899999999999977" y="7519."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re14.L" x="469.899999999999977" y="7524."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re14.R" x="479.899999999999977" y="7524."/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re15">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="770.899999999999977" y="7229.699999999999818"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_
100000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re106.R" x="6736.399999999999636" y="7026.100000000000364"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re110">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="6063.699999999999818" y="2613."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re110.L" x="6063.699999999999818" y="2618."/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re110.R" x="6073.699999999999818" y="2618."/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re111">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="5970.199999999999818" y="2706.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re111.L" x="5970.199999999999818" y="2711.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re111.R" x="5980.199999999999818" y="2711.5"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re112">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="5972.600000000000364" y="2841.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re112.L" x="5972.600000000000364" y="2846.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re112.R" x="5982.600000000000364" y="2846.800000000000182"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re113">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="7267.199999999999818" y="6381.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re113.L" x="7267.199999999999818" y="6386.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re113.R" x="7277.199999999999818" y="6386.5"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re114">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="6853.100000000000364" y="6533.899999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re114.L" x="6853.100000000000364" y="6538.899999999999636"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re114.R" x="6863.100000000000364" y="6538.899999999999636"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re115">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="4736.5" y="4623.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re115.L" x="4736.5" y="4628.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re115.R" x="4746.5" y="4628.800000000000182"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re118">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="6157.300000000000182" y="2703.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re118.L" x="6157.300000000000182" y="2708.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re118.R" x="6167.300000000000182" y="2708.5"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re119">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="5136.800000000000182" y="4624.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re119.L" x="5136.800000000000182" y="4629.800000000000182"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re119.R" x="5146.800000000000182" y="4629.800000000000182"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re120">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="5124." y="4952.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re120.L" x="5124." y="4957.5"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re120.R" x="5134." y="4957.5"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re121">
#             <sbgn:bbox xmlns:sbgn="http://sbgn.org/libsbgn/0.2" w="10." h="10." x="7646.600000000000364" y="6911.100000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re121.L" x="7646.600000000000364" y="6916.100000000000364"/>
#             <sbgn:port xmlns:sbgn="http://sbgn.org/libsbgn/0.2" id="pnd_re121.R" x="7656.600000000000364" y="6916.100000000000364"/>
#         </sbgn:glyph>
#         <sbgn:glyph xmlns:sbgn="http://sbgn.org/libsbgn/0.2" class="process" id="pnd_re122">
# ...
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.MODULATION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CATALYSIS
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION
#  Arc with class  ArcClass.CONSUMPTION
#  Arc with class  ArcClass.PRODUCTION

# %%
render_sbgn(sbgn, "dnarepair.png")
# Out:
# SBGN rendered: dnarepair.png

# %%
smap = sbgn.get_map()

# %%
glyphs = smap.get_glyph()

# %%
def print_glyph(glyph):
    cls = glyph.get_class()
    print(cls)
    print("\tid: ", glyph.get_id())
    label = glyph.get_label()
    try:
        label_text = label.get_text()
        print('\tlabel: ', label_text)
    except:
        print('\tlabel: no label')

    if cls == 'process':
        for p in glyph.get_port():
            try:
                print('\t port ', p.get_id(), p.get_x(), p.get_y())
            except:
                print("\t port: no port")

    box = glyph.get_bbox()
    print('\tx, y, w, h : ', box.get_x(), box.get_y(), box.get_w(), box.get_h())
    print("\n")

# %%
glyphs_with_glyphs = []
for i, glyph in enumerate(glyphs):
    sub_glyphs = glyph.get_glyph()
    if sub_glyphs:
        glyphs_with_glyphs.append(glyph)
    cls = glyph.get_class()
    print(cls)
    print("\tid: ", glyph.get_id())
    label = glyph.get_label()
    try:
        label_text = label.get_text()
        print('\tlabel: ', label_text)
    except:
        print('\tlabel: no label')

    if cls == 'process':
        for p in glyph.get_port():
            try:
                print('\t port ', p.get_id(), p.get_x(), p.get_y())
            except:
                print("\t port: no port")

    box = glyph.get_bbox()
    print('\tx, y, w, h : ', box.get_x(), box.get_y(), box.get_w(), box.get_h())
    print("\n")
# Out:
# GlyphClass.PROCESS
# 	id:  pnd_re1
# 	label: no label
# 	x, y, w, h :  2966.6 7373.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re2
# 	label: no label
# 	x, y, w, h :  2413.2 7688.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re3
# 	label: no label
# 	x, y, w, h :  1859.9 8041.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re4
# 	label: no label
# 	x, y, w, h :  2966.6 7659.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re5
# 	label: no label
# 	x, y, w, h :  2965.6 7091.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re6
# 	label: no label
# 	x, y, w, h :  1867.9 7154.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re7
# 	label: no label
# 	x, y, w, h :  1859.9 7484.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re8
# 	label: no label
# 	x, y, w, h :  2227.0 7729.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re9
# 	label: no label
# 	x, y, w, h :  1859.9 7736.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re10
# 	label: no label
# 	x, y, w, h :  3410.4 7708.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re11
# 	label: no label
# 	x, y, w, h :  2238.1 8412.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re12
# 	label: no label
# 	x, y, w, h :  1010.4 7519.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re13
# 	label: no label
# 	x, y, w, h :  231.9 7142.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re14
# 	label: no label
# 	x, y, w, h :  469.9 7519.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re15
# 	label: no label
# 	x, y, w, h :  770.9 7229.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re16
# 	label: no label
# 	x, y, w, h :  970.3 7640.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re17
# 	label: no label
# 	x, y, w, h :  717.9 8366.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re18
# 	label: no label
# 	x, y, w, h :  525.4 7094.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re19
# 	label: no label
# 	x, y, w, h :  1629.6 7153.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re20
# 	label: no label
# 	x, y, w, h :  1859.9 8318.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re21
# 	label: no label
# 	x, y, w, h :  2966.6 8284.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re22
# 	label: no label
# 	x, y, w, h :  2305.7 8226.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re23
# 	label: no label
# 	x, y, w, h :  1409.4 8165.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re24
# 	label: no label
# 	x, y, w, h :  3460.6 7983.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re25
# 	label: no label
# 	x, y, w, h :  3477.2 8271.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re26
# 	label: no label
# 	x, y, w, h :  3757.2 7149.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re27
# 	label: no label
# 	x, y, w, h :  717.9 7817.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re28
# 	label: no label
# 	x, y, w, h :  717.9 8133.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re29
# 	label: no label
# 	x, y, w, h :  3757.2 7383.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re30
# 	label: no label
# 	x, y, w, h :  3757.2 7634.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re31
# 	label: no label
# 	x, y, w, h :  3757.2 7848.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re32
# 	label: no label
# 	x, y, w, h :  2963.3 2696.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re33
# 	label: no label
# 	x, y, w, h :  5455.4 3303.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re34
# 	label: no label
# 	x, y, w, h :  3434.4 2705.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re36
# 	label: no label
# 	x, y, w, h :  4702.3 3299.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re37
# 	label: no label
# 	x, y, w, h :  3992.6 3303.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re38
# 	label: no label
# 	x, y, w, h :  2427.0 7292.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re39
# 	label: no label
# 	x, y, w, h :  2406.3 7365.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re40
# 	label: no label
# 	x, y, w, h :  3795.4 7192.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re41
# 	label: no label
# 	x, y, w, h :  5800.1 2706.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re43
# 	label: no label
# 	x, y, w, h :  5318.8 7345.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re44
# 	label: no label
# 	x, y, w, h :  5182.8 7340.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re45
# 	label: no label
# 	x, y, w, h :  4234.8 7638.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re46
# 	label: no label
# 	x, y, w, h :  6077.5 7422.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re47
# 	label: no label
# 	x, y, w, h :  3766.8 2908.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re48
# 	label: no label
# 	x, y, w, h :  3488.3 2628.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re49
# 	label: no label
# 	x, y, w, h :  3203.9 2704.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re50
# 	label: no label
# 	x, y, w, h :  3260.1 2769.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re51
# 	label: no label
# 	x, y, w, h :  3911.9 2912.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re52
# 	label: no label
# 	x, y, w, h :  3856.5 2986.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re54
# 	label: no label
# 	x, y, w, h :  5326.9 5210.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re57
# 	label: no label
# 	x, y, w, h :  5419.6 5300.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re58
# 	label: no label
# 	x, y, w, h :  5512.8 5265.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re59
# 	label: no label
# 	x, y, w, h :  4367.8 2914.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re60
# 	label: no label
# 	x, y, w, h :  4489.5 2919.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re61
# 	label: no label
# 	x, y, w, h :  4187.2 2699.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re63
# 	label: no label
# 	x, y, w, h :  5269.0 1781.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re65
# 	label: no label
# 	x, y, w, h :  4678.0 1783.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re68
# 	label: no label
# 	x, y, w, h :  4998.2 1783.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re70
# 	label: no label
# 	x, y, w, h :  2420.0 8366.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re71
# 	label: no label
# 	x, y, w, h :  7501.3 6716.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re73
# 	label: no label
# 	x, y, w, h :  5879.2 3303.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re74
# 	label: no label
# 	x, y, w, h :  7643.8 6715.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re75
# 	label: no label
# 	x, y, w, h :  2200.4 7289.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re76
# 	label: no label
# 	x, y, w, h :  2226.6 7409.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re77
# 	label: no label
# 	x, y, w, h :  3325.4 7247.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re78
# 	label: no label
# 	x, y, w, h :  2224.1 7050.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re79
# 	label: no label
# 	x, y, w, h :  5786.3 7116.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re80
# 	label: no label
# 	x, y, w, h :  5520.2 7160.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re81
# 	label: no label
# 	x, y, w, h :  5520.2 7956.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re82
# 	label: no label
# 	x, y, w, h :  6211.4 7846.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re83
# 	label: no label
# 	x, y, w, h :  6065.1 7849.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re85
# 	label: no label
# 	x, y, w, h :  5914.3 8216.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re86
# 	label: no label
# 	x, y, w, h :  6077.8 8213.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re90
# 	label: no label
# 	x, y, w, h :  6346.4 2701.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re91
# 	label: no label
# 	x, y, w, h :  7530.0 6242.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re92
# 	label: no label
# 	x, y, w, h :  6346.4 2701.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re93
# 	label: no label
# 	x, y, w, h :  5834.2 5284.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re94
# 	label: no label
# 	x, y, w, h :  6095.6 7906.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re95
# 	label: no label
# 	x, y, w, h :  5888.2 7860.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re96
# 	label: no label
# 	x, y, w, h :  5520.2 8218.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re97
# 	label: no label
# 	x, y, w, h :  7277.4 6226.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re98
# 	label: no label
# 	x, y, w, h :  2966.6 7986.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re104
# 	label: no label
# 	x, y, w, h :  4135.3 7444.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re105
# 	label: no label
# 	x, y, w, h :  6314.2 7156.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re106
# 	label: no label
# 	x, y, w, h :  6726.4 7021.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re110
# 	label: no label
# 	x, y, w, h :  6063.7 2613.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re111
# 	label: no label
# 	x, y, w, h :  5970.2 2706.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re112
# 	label: no label
# 	x, y, w, h :  5972.6 2841.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re113
# 	label: no label
# 	x, y, w, h :  7267.2 6381.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re114
# 	label: no label
# 	x, y, w, h :  6853.1 6533.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re115
# 	label: no label
# 	x, y, w, h :  4736.5 4623.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re118
# 	label: no label
# 	x, y, w, h :  6157.3 2703.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re119
# 	label: no label
# 	x, y, w, h :  5136.8 4624.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re120
# 	label: no label
# 	x, y, w, h :  5124.0 4952.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re121
# 	label: no label
# 	x, y, w, h :  7646.6 6911.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re122
# 	label: no label
# 	x, y, w, h :  6641.8 7336.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re123
# 	label: no label
# 	x, y, w, h :  6314.2 7444.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re124
# 	label: no label
# 	x, y, w, h :  5335.0 7636.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re125
# 	label: no label
# 	x, y, w, h :  6314.2 7678.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re126
# 	label: no label
# 	x, y, w, h :  6314.2 7946.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re127
# 	label: no label
# 	x, y, w, h :  6314.2 8222.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re128
# 	label: no label
# 	x, y, w, h :  6621.0 8332.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re129
# 	label: no label
# 	x, y, w, h :  5953.8 7130.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re130
# 	label: no label
# 	x, y, w, h :  6077.9 7135.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re131
# 	label: no label
# 	x, y, w, h :  7315.0 7424.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re132
# 	label: no label
# 	x, y, w, h :  7517.7 7386.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re134
# 	label: no label
# 	x, y, w, h :  7254.7 5964.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re135
# 	label: no label
# 	x, y, w, h :  7267.4 6685.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re136
# 	label: no label
# 	x, y, w, h :  6853.1 7724.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re137
# 	label: no label
# 	x, y, w, h :  7760.6 7792.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re138
# 	label: no label
# 	x, y, w, h :  7750.7 7684.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re139
# 	label: no label
# 	x, y, w, h :  6853.1 8355.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re140
# 	label: no label
# 	x, y, w, h :  6853.1 8564.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re141
# 	label: no label
# 	x, y, w, h :  6853.1 8768.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re142
# 	label: no label
# 	x, y, w, h :  7385.1 8840.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re143
# 	label: no label
# 	x, y, w, h :  7383.4 9015.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re144
# 	label: no label
# 	x, y, w, h :  6853.1 8946.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re145
# 	label: no label
# 	x, y, w, h :  7768.0 7930.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re146
# 	label: no label
# 	x, y, w, h :  7433.9 7666.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re147
# 	label: no label
# 	x, y, w, h :  7141.2 5376.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re148
# 	label: no label
# 	x, y, w, h :  7451.9 6958.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re149
# 	label: no label
# 	x, y, w, h :  7257.1 6959.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re150
# 	label: no label
# 	x, y, w, h :  8470.5 6791.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re151
# 	label: no label
# 	x, y, w, h :  8764.0 6938.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re152
# 	label: no label
# 	x, y, w, h :  3276.8 1113.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re153
# 	label: no label
# 	x, y, w, h :  9189.6 8452.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re154
# 	label: no label
# 	x, y, w, h :  9197.6 8181.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re155
# 	label: no label
# 	x, y, w, h :  9211.1 8349.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re156
# 	label: no label
# 	x, y, w, h :  8472.8 7126.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re157
# 	label: no label
# 	x, y, w, h :  8902.0 8250.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re158
# 	label: no label
# 	x, y, w, h :  7780.4 7481.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re159
# 	label: no label
# 	x, y, w, h :  9312.2 7931.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re160
# 	label: no label
# 	x, y, w, h :  9477.2 7935.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re161
# 	label: no label
# 	x, y, w, h :  9076.9 7911.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re162
# 	label: no label
# 	x, y, w, h :  8472.8 7515.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re163
# 	label: no label
# 	x, y, w, h :  8472.8 7908.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re164
# 	label: no label
# 	x, y, w, h :  4595.4 7996.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re165
# 	label: no label
# 	x, y, w, h :  7663.0 7512.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re166
# 	label: no label
# 	x, y, w, h :  7766.2 8100.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re167
# 	label: no label
# 	x, y, w, h :  7596.5 8038.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re168
# 	label: no label
# 	x, y, w, h :  8992.8 7631.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re169
# 	label: no label
# 	x, y, w, h :  9884.3 7064.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re170
# 	label: no label
# 	x, y, w, h :  9735.5 7267.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re172
# 	label: no label
# 	x, y, w, h :  9719.4 7450.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re173
# 	label: no label
# 	x, y, w, h :  9228.6 7215.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re174
# 	label: no label
# 	x, y, w, h :  9646.5 7397.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re175
# 	label: no label
# 	x, y, w, h :  2536.5 6777.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re176
# 	label: no label
# 	x, y, w, h :  3078.5 6593.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re177
# 	label: no label
# 	x, y, w, h :  3363.4 6558.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re178
# 	label: no label
# 	x, y, w, h :  3907.8 6557.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re179
# 	label: no label
# 	x, y, w, h :  4304.1 6605.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re180
# 	label: no label
# 	x, y, w, h :  4822.5 7427.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re181
# 	label: no label
# 	x, y, w, h :  7679.3 7024.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re182
# 	label: no label
# 	x, y, w, h :  9945.9 7319.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re183
# 	label: no label
# 	x, y, w, h :  10051.6 7338.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re184
# 	label: no label
# 	x, y, w, h :  9310.9 7330.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re185
# 	label: no label
# 	x, y, w, h :  9757.8 6855.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re186
# 	label: no label
# 	x, y, w, h :  9354.4 8502.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re187
# 	label: no label
# 	x, y, w, h :  7919.7 7487.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re188
# 	label: no label
# 	x, y, w, h :  9463.7 8156.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re189
# 	label: no label
# 	x, y, w, h :  7521.8 6567.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re190
# 	label: no label
# 	x, y, w, h :  9387.6 7834.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re191
# 	label: no label
# 	x, y, w, h :  9312.2 7931.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re192
# 	label: no label
# 	x, y, w, h :  7762.5 7497.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re193
# 	label: no label
# 	x, y, w, h :  9518.2 7808.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re194
# 	label: no label
# 	x, y, w, h :  9014.2 6950.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re195
# 	label: no label
# 	x, y, w, h :  9157.0 6938.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re196
# 	label: no label
# 	x, y, w, h :  3482.7 7296.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re197
# 	label: no label
# 	x, y, w, h :  3591.3 7297.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re198
# 	label: no label
# 	x, y, w, h :  8100.2 7477.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re199
# 	label: no label
# 	x, y, w, h :  5674.9 4725.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re200
# 	label: no label
# 	x, y, w, h :  8665.8 8421.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re203
# 	label: no label
# 	x, y, w, h :  7249.0 6533.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re204
# 	label: no label
# 	x, y, w, h :  7408.5 7422.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re205
# 	label: no label
# 	x, y, w, h :  7655.4 6203.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re206
# 	label: no label
# 	x, y, w, h :  6668.1 5695.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re207
# 	label: no label
# 	x, y, w, h :  8030.3 7612.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re208
# 	label: no label
# 	x, y, w, h :  8401.1 7500.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re209
# 	label: no label
# 	x, y, w, h :  5873.2 5724.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re210
# 	label: no label
# 	x, y, w, h :  7201.6 8444.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re211
# 	label: no label
# 	x, y, w, h :  9170.9 8073.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re212
# 	label: no label
# 	x, y, w, h :  7355.1 8432.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re213
# 	label: no label
# 	x, y, w, h :  9454.2 8069.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re214
# 	label: no label
# 	x, y, w, h :  9568.7 8070.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re215
# 	label: no label
# 	x, y, w, h :  6186.6 6443.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re216
# 	label: no label
# 	x, y, w, h :  4723.8 4951.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re218
# 	label: no label
# 	x, y, w, h :  7318.4 8025.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re219
# 	label: no label
# 	x, y, w, h :  5852.0 6010.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re220
# 	label: no label
# 	x, y, w, h :  7660.6 6202.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re221
# 	label: no label
# 	x, y, w, h :  4974.9 4527.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re222
# 	label: no label
# 	x, y, w, h :  7244.2 5802.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re223
# 	label: no label
# 	x, y, w, h :  7300.5 6834.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re224
# 	label: no label
# 	x, y, w, h :  7914.5 2398.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re225
# 	label: no label
# 	x, y, w, h :  8732.7 5101.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re226
# 	label: no label
# 	x, y, w, h :  7914.5 1752.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re227
# 	label: no label
# 	x, y, w, h :  5170.6 4803.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re228
# 	label: no label
# 	x, y, w, h :  7915.3 2008.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re229
# 	label: no label
# 	x, y, w, h :  4851.6 4560.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re230
# 	label: no label
# 	x, y, w, h :  5707.6 4560.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re231
# 	label: no label
# 	x, y, w, h :  7914.5 1881.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re232
# 	label: no label
# 	x, y, w, h :  7914.5 2269.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re233
# 	label: no label
# 	x, y, w, h :  8036.2 5023.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re234
# 	label: no label
# 	x, y, w, h :  1036.6 7223.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re235
# 	label: no label
# 	x, y, w, h :  1107.8 7172.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re236
# 	label: no label
# 	x, y, w, h :  9700.3 7219.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re237
# 	label: no label
# 	x, y, w, h :  4775.6 7126.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re238
# 	label: no label
# 	x, y, w, h :  4775.6 7356.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re239
# 	label: no label
# 	x, y, w, h :  4775.6 7679.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re240
# 	label: no label
# 	x, y, w, h :  4775.6 7998.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re241
# 	label: no label
# 	x, y, w, h :  4778.6 8226.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re242
# 	label: no label
# 	x, y, w, h :  5182.8 7350.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re243
# 	label: no label
# 	x, y, w, h :  5912.6 8347.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re244
# 	label: no label
# 	x, y, w, h :  5031.4 7820.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re245
# 	label: no label
# 	x, y, w, h :  5535.8 7813.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re246
# 	label: no label
# 	x, y, w, h :  5220.5 7637.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re247
# 	label: no label
# 	x, y, w, h :  8992.8 7631.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re248
# 	label: no label
# 	x, y, w, h :  7196.3 7986.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re249
# 	label: no label
# 	x, y, w, h :  7413.8 8218.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re250
# 	label: no label
# 	x, y, w, h :  7834.2 7653.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re251
# 	label: no label
# 	x, y, w, h :  7563.2 7280.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re252
# 	label: no label
# 	x, y, w, h :  1304.5 7196.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re253
# 	label: no label
# 	x, y, w, h :  1721.1 7329.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re254
# 	label: no label
# 	x, y, w, h :  3162.7 7454.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re255
# 	label: no label
# 	x, y, w, h :  4512.3 7330.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re256
# 	label: no label
# 	x, y, w, h :  4514.8 7458.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re257
# 	label: no label
# 	x, y, w, h :  3500.6 7098.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re258
# 	label: no label
# 	x, y, w, h :  4522.0 7209.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re259
# 	label: no label
# 	x, y, w, h :  4109.5 7230.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re260
# 	label: no label
# 	x, y, w, h :  5108.8 3316.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re262
# 	label: no label
# 	x, y, w, h :  4804.1 1393.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re263
# 	label: no label
# 	x, y, w, h :  4980.5 1378.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re264
# 	label: no label
# 	x, y, w, h :  3809.5 1093.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re265
# 	label: no label
# 	x, y, w, h :  3814.5 974.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re266
# 	label: no label
# 	x, y, w, h :  3701.8 1148.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re267
# 	label: no label
# 	x, y, w, h :  4532.3 955.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re268
# 	label: no label
# 	x, y, w, h :  4893.6 556.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re269
# 	label: no label
# 	x, y, w, h :  4266.2 551.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re270
# 	label: no label
# 	x, y, w, h :  5445.4 612.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re271
# 	label: no label
# 	x, y, w, h :  5472.5 2213.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re272
# 	label: no label
# 	x, y, w, h :  4794.1 729.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re273
# 	label: no label
# 	x, y, w, h :  5616.0 2201.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re274
# 	label: no label
# 	x, y, w, h :  5909.0 2200.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re275
# 	label: no label
# 	x, y, w, h :  4916.8 1428.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re276
# 	label: no label
# 	x, y, w, h :  3690.5 695.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re277
# 	label: no label
# 	x, y, w, h :  3745.9 1888.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re278
# 	label: no label
# 	x, y, w, h :  3758.5 1554.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re279
# 	label: no label
# 	x, y, w, h :  4135.0 2078.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re280
# 	label: no label
# 	x, y, w, h :  4137.0 2018.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re281
# 	label: no label
# 	x, y, w, h :  4124.5 1614.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re282
# 	label: no label
# 	x, y, w, h :  4124.5 1561.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re283
# 	label: no label
# 	x, y, w, h :  5339.4 2235.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re284
# 	label: no label
# 	x, y, w, h :  4699.4 1320.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re285
# 	label: no label
# 	x, y, w, h :  4658.4 1283.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re286
# 	label: no label
# 	x, y, w, h :  4799.6 1370.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re287
# 	label: no label
# 	x, y, w, h :  4489.3 956.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re288
# 	label: no label
# 	x, y, w, h :  4333.3 589.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re289
# 	label: no label
# 	x, y, w, h :  5224.0 661.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re290
# 	label: no label
# 	x, y, w, h :  4493.7 565.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re291
# 	label: no label
# 	x, y, w, h :  3695.9 1869.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re292
# 	label: no label
# 	x, y, w, h :  3747.1 1614.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re293
# 	label: no label
# 	x, y, w, h :  5432.6 2204.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re294
# 	label: no label
# 	x, y, w, h :  4752.8 1083.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re295
# 	label: no label
# 	x, y, w, h :  4777.6 1100.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re296
# 	label: no label
# 	x, y, w, h :  3811.9 992.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re297
# 	label: no label
# 	x, y, w, h :  3835.3 606.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re298
# 	label: no label
# 	x, y, w, h :  5342.1 619.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re299
# 	label: no label
# 	x, y, w, h :  4784.4 1028.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re300
# 	label: no label
# 	x, y, w, h :  4888.7 1089.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re301
# 	label: no label
# 	x, y, w, h :  5008.3 1133.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re302
# 	label: no label
# 	x, y, w, h :  4750.5 669.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re303
# 	label: no label
# 	x, y, w, h :  746.0 6866.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re304
# 	label: no label
# 	x, y, w, h :  4769.3 872.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re305
# 	label: no label
# 	x, y, w, h :  5764.0 2200.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re306
# 	label: no label
# 	x, y, w, h :  3907.1 530.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re307
# 	label: no label
# 	x, y, w, h :  4054.7 531.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re308
# 	label: no label
# 	x, y, w, h :  4718.0 1783.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re309
# 	label: no label
# 	x, y, w, h :  4696.3 1898.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re310
# 	label: no label
# 	x, y, w, h :  4963.2 1901.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re311
# 	label: no label
# 	x, y, w, h :  5003.2 1901.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re312
# 	label: no label
# 	x, y, w, h :  4958.2 1783.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re313
# 	label: no label
# 	x, y, w, h :  5289.4 1897.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re314
# 	label: no label
# 	x, y, w, h :  5280.5 3878.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re315
# 	label: no label
# 	x, y, w, h :  5924.7 3657.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re316
# 	label: no label
# 	x, y, w, h :  5309.0 1781.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re317
# 	label: no label
# 	x, y, w, h :  3948.0 1090.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re318
# 	label: no label
# 	x, y, w, h :  4086.5 1089.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re319
# 	label: no label
# 	x, y, w, h :  4231.3 1089.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re320
# 	label: no label
# 	x, y, w, h :  3881.0 1175.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re321
# 	label: no label
# 	x, y, w, h :  3787.1 1257.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re322
# 	label: no label
# 	x, y, w, h :  3736.8 1167.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re323
# 	label: no label
# 	x, y, w, h :  4659.9 1502.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re324
# 	label: no label
# 	x, y, w, h :  4982.5 1407.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re325
# 	label: no label
# 	x, y, w, h :  3771.0 538.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re326
# 	label: no label
# 	x, y, w, h :  4771.2 5758.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re327
# 	label: no label
# 	x, y, w, h :  7912.6 459.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re328
# 	label: no label
# 	x, y, w, h :  5835.9 479.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re329
# 	label: no label
# 	x, y, w, h :  4205.4 532.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re330
# 	label: no label
# 	x, y, w, h :  7912.1 589.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re331
# 	label: no label
# 	x, y, w, h :  5835.5 630.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re332
# 	label: no label
# 	x, y, w, h :  3770.0 521.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re333
# 	label: no label
# 	x, y, w, h :  3690.5 465.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re334
# 	label: no label
# 	x, y, w, h :  5413.5 517.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re335
# 	label: no label
# 	x, y, w, h :  5562.5 517.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re336
# 	label: no label
# 	x, y, w, h :  5719.8 516.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re340
# 	label: no label
# 	x, y, w, h :  5377.0 1720.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re341
# 	label: no label
# 	x, y, w, h :  5451.7 1593.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re342
# 	label: no label
# 	x, y, w, h :  5603.0 1593.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re343
# 	label: no label
# 	x, y, w, h :  5754.3 1594.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re344
# 	label: no label
# 	x, y, w, h :  7912.1 847.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re345
# 	label: no label
# 	x, y, w, h :  6339.1 760.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re346
# 	label: no label
# 	x, y, w, h :  7914.5 1106.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re347
# 	label: no label
# 	x, y, w, h :  6686.8 1672.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re352
# 	label: no label
# 	x, y, w, h :  5384.8 1008.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re353
# 	label: no label
# 	x, y, w, h :  5379.2 1305.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re355
# 	label: no label
# 	x, y, w, h :  5813.7 1074.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re357
# 	label: no label
# 	x, y, w, h :  6101.2 1285.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re358
# 	label: no label
# 	x, y, w, h :  5830.0 1689.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re360
# 	label: no label
# 	x, y, w, h :  5984.5 2284.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re361
# 	label: no label
# 	x, y, w, h :  5097.7 2708.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re364
# 	label: no label
# 	x, y, w, h :  3993.3 5523.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re365
# 	label: no label
# 	x, y, w, h :  3571.8 1450.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re366
# 	label: no label
# 	x, y, w, h :  7914.5 1235.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re367
# 	label: no label
# 	x, y, w, h :  5782.5 1362.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re368
# 	label: no label
# 	x, y, w, h :  4754.1 1839.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re369
# 	label: no label
# 	x, y, w, h :  5035.6 1835.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re370
# 	label: no label
# 	x, y, w, h :  4919.6 731.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re371
# 	label: no label
# 	x, y, w, h :  4186.0 1797.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re372
# 	label: no label
# 	x, y, w, h :  4304.7 1794.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re373
# 	label: no label
# 	x, y, w, h :  3331.7 1604.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re374
# 	label: no label
# 	x, y, w, h :  5212.4 5963.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re375
# 	label: no label
# 	x, y, w, h :  3580.8 5339.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re376
# 	label: no label
# 	x, y, w, h :  3759.3 5332.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re377
# 	label: no label
# 	x, y, w, h :  3728.3 5214.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re379
# 	label: no label
# 	x, y, w, h :  3276.0 2009.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re380
# 	label: no label
# 	x, y, w, h :  3254.2 2085.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re383
# 	label: no label
# 	x, y, w, h :  3294.2 2085.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re384
# 	label: no label
# 	x, y, w, h :  3159.5 2174.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re385
# 	label: no label
# 	x, y, w, h :  3159.6 2202.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re386
# 	label: no label
# 	x, y, w, h :  4059.8 4280.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re387
# 	label: no label
# 	x, y, w, h :  3401.5 5338.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re388
# 	label: no label
# 	x, y, w, h :  3304.5 5339.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re389
# 	label: no label
# 	x, y, w, h :  4091.4 5091.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re390
# 	label: no label
# 	x, y, w, h :  4091.8 5136.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re391
# 	label: no label
# 	x, y, w, h :  4091.8 5136.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re392
# 	label: no label
# 	x, y, w, h :  4091.4 5091.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re394
# 	label: no label
# 	x, y, w, h :  3741.5 2078.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re395
# 	label: no label
# 	x, y, w, h :  5764.0 2200.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re396
# 	label: no label
# 	x, y, w, h :  4054.4 1869.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re397
# 	label: no label
# 	x, y, w, h :  5454.7 5349.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re398
# 	label: no label
# 	x, y, w, h :  4578.7 2658.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re399
# 	label: no label
# 	x, y, w, h :  7912.1 718.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re400
# 	label: no label
# 	x, y, w, h :  5861.1 862.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re401
# 	label: no label
# 	x, y, w, h :  4737.9 2812.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re402
# 	label: no label
# 	x, y, w, h :  7912.1 976.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re403
# 	label: no label
# 	x, y, w, h :  5858.9 1051.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re404
# 	label: no label
# 	x, y, w, h :  4439.2 2747.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re405
# 	label: no label
# 	x, y, w, h :  4770.4 1216.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re406
# 	label: no label
# 	x, y, w, h :  7914.5 1364.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re407
# 	label: no label
# 	x, y, w, h :  6344.4 1601.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re408
# 	label: no label
# 	x, y, w, h :  4291.1 2968.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re409
# 	label: no label
# 	x, y, w, h :  4430.8 3577.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re410
# 	label: no label
# 	x, y, w, h :  5570.1 2139.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re411
# 	label: no label
# 	x, y, w, h :  5076.2 1920.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re412
# 	label: no label
# 	x, y, w, h :  5395.3 1921.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re413
# 	label: no label
# 	x, y, w, h :  7908.5 2527.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re414
# 	label: no label
# 	x, y, w, h :  6487.5 2333.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re415
# 	label: no label
# 	x, y, w, h :  3875.3 2709.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re416
# 	label: no label
# 	x, y, w, h :  3835.3 2709.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re417
# 	label: no label
# 	x, y, w, h :  3605.7 2712.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re418
# 	label: no label
# 	x, y, w, h :  3645.7 2712.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re420
# 	label: no label
# 	x, y, w, h :  4242.4 6991.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re421
# 	label: no label
# 	x, y, w, h :  4601.9 6961.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re422
# 	label: no label
# 	x, y, w, h :  4908.8 6394.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re423
# 	label: no label
# 	x, y, w, h :  8006.8 7777.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re424
# 	label: no label
# 	x, y, w, h :  2433.6 8146.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re425
# 	label: no label
# 	x, y, w, h :  2434.6 8157.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re426
# 	label: no label
# 	x, y, w, h :  4310.4 5033.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re427
# 	label: no label
# 	x, y, w, h :  3998.3 5393.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re428
# 	label: no label
# 	x, y, w, h :  4351.3 2366.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re429
# 	label: no label
# 	x, y, w, h :  5520.4 5384.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re430
# 	label: no label
# 	x, y, w, h :  8077.6 7723.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re431
# 	label: no label
# 	x, y, w, h :  8144.0 7599.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re433
# 	label: no label
# 	x, y, w, h :  6069.8 3271.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re434
# 	label: no label
# 	x, y, w, h :  7914.5 1493.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re435
# 	label: no label
# 	x, y, w, h :  7914.5 1622.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re436
# 	label: no label
# 	x, y, w, h :  6015.6 3381.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re437
# 	label: no label
# 	x, y, w, h :  6296.5 752.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re438
# 	label: no label
# 	x, y, w, h :  4145.3 7320.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re439
# 	label: no label
# 	x, y, w, h :  4354.1 7429.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re440
# 	label: no label
# 	x, y, w, h :  4355.1 7364.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re441
# 	label: no label
# 	x, y, w, h :  4144.5 7219.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re442
# 	label: no label
# 	x, y, w, h :  4350.0 7264.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re443
# 	label: no label
# 	x, y, w, h :  5507.0 4602.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re444
# 	label: no label
# 	x, y, w, h :  5320.9 2820.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re445
# 	label: no label
# 	x, y, w, h :  5569.9 3936.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re446
# 	label: no label
# 	x, y, w, h :  3565.5 2236.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re447
# 	label: no label
# 	x, y, w, h :  5574.9 2704.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re448
# 	label: no label
# 	x, y, w, h :  3565.5 2131.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re449
# 	label: no label
# 	x, y, w, h :  5318.5 2701.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re450
# 	label: no label
# 	x, y, w, h :  7503.8 6069.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re451
# 	label: no label
# 	x, y, w, h :  7503.8 6126.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re452
# 	label: no label
# 	x, y, w, h :  7144.3 2321.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re453
# 	label: no label
# 	x, y, w, h :  7207.7 2748.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re454
# 	label: no label
# 	x, y, w, h :  7264.6 6095.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re455
# 	label: no label
# 	x, y, w, h :  5553.5 4941.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re456
# 	label: no label
# 	x, y, w, h :  3309.6 7555.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re457
# 	label: no label
# 	x, y, w, h :  5340.2 4750.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re458
# 	label: no label
# 	x, y, w, h :  5397.4 4300.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re459
# 	label: no label
# 	x, y, w, h :  3507.4 7553.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re460
# 	label: no label
# 	x, y, w, h :  6165.8 3654.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re461
# 	label: no label
# 	x, y, w, h :  6105.6 3629.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re463
# 	label: no label
# 	x, y, w, h :  5976.4 4536.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re465
# 	label: no label
# 	x, y, w, h :  6522.0 1122.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re467
# 	label: no label
# 	x, y, w, h :  5185.6 6607.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re468
# 	label: no label
# 	x, y, w, h :  5582.6 6581.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re470
# 	label: no label
# 	x, y, w, h :  4813.3 6606.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re471
# 	label: no label
# 	x, y, w, h :  6009.0 4647.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re472
# 	label: no label
# 	x, y, w, h :  5679.1 1882.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re473
# 	label: no label
# 	x, y, w, h :  5930.0 3708.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re474
# 	label: no label
# 	x, y, w, h :  5458.0 4223.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re475
# 	label: no label
# 	x, y, w, h :  3698.0 6992.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re476
# 	label: no label
# 	x, y, w, h :  4057.5 6969.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re477
# 	label: no label
# 	x, y, w, h :  4364.5 6394.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re478
# 	label: no label
# 	x, y, w, h :  2261.1 7151.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re479
# 	label: no label
# 	x, y, w, h :  2251.8 7513.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re480
# 	label: no label
# 	x, y, w, h :  3325.6 7399.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re481
# 	label: no label
# 	x, y, w, h :  106.8 7156.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re482
# 	label: no label
# 	x, y, w, h :  383.8 6883.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re483
# 	label: no label
# 	x, y, w, h :  337.1 6822.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re484
# 	label: no label
# 	x, y, w, h :  1227.5 8335.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re485
# 	label: no label
# 	x, y, w, h :  7914.5 2139.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re486
# 	label: no label
# 	x, y, w, h :  6722.9 2655.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re488
# 	label: no label
# 	x, y, w, h :  6788.7 3974.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re489
# 	label: no label
# 	x, y, w, h :  9411.0 6954.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re490
# 	label: no label
# 	x, y, w, h :  9728.2 7462.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re491
# 	label: no label
# 	x, y, w, h :  4822.0 8512.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re492
# 	label: no label
# 	x, y, w, h :  2425.6 7676.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re494
# 	label: no label
# 	x, y, w, h :  5520.2 7543.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re495
# 	label: no label
# 	x, y, w, h :  6171.4 8307.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re496
# 	label: no label
# 	x, y, w, h :  5803.8 7617.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re497
# 	label: no label
# 	x, y, w, h :  10093.5 6970.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re498
# 	label: no label
# 	x, y, w, h :  7170.4 6534.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re499
# 	label: no label
# 	x, y, w, h :  7521.0 6524.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re500
# 	label: no label
# 	x, y, w, h :  2741.2 8573.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re501
# 	label: no label
# 	x, y, w, h :  3322.7 8547.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re502
# 	label: no label
# 	x, y, w, h :  3863.0 8545.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re504
# 	label: no label
# 	x, y, w, h :  4257.6 8300.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re505
# 	label: no label
# 	x, y, w, h :  4787.8 8492.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re506
# 	label: no label
# 	x, y, w, h :  5175.1 8507.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re507
# 	label: no label
# 	x, y, w, h :  5571.3 8520.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re508
# 	label: no label
# 	x, y, w, h :  5874.5 8854.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re509
# 	label: no label
# 	x, y, w, h :  7108.5 7856.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re510
# 	label: no label
# 	x, y, w, h :  7443.8 7873.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re511
# 	label: no label
# 	x, y, w, h :  3907.8 6632.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re512
# 	label: no label
# 	x, y, w, h :  4840.4 6681.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re513
# 	label: no label
# 	x, y, w, h :  5185.6 6682.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re514
# 	label: no label
# 	x, y, w, h :  5582.6 6656.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re515
# 	label: no label
# 	x, y, w, h :  5879.2 6072.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re516
# 	label: no label
# 	x, y, w, h :  7116.0 6588.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re517
# 	label: no label
# 	x, y, w, h :  3078.5 6661.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re518
# 	label: no label
# 	x, y, w, h :  7526.5 6583.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re519
# 	label: no label
# 	x, y, w, h :  2597.6 6614.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re520
# 	label: no label
# 	x, y, w, h :  6629.5 6427.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re523
# 	label: no label
# 	x, y, w, h :  8175.5 7776.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re524
# 	label: no label
# 	x, y, w, h :  8337.8 7777.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re525
# 	label: no label
# 	x, y, w, h :  9489.8 8501.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re526
# 	label: no label
# 	x, y, w, h :  9607.3 8504.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re527
# 	label: no label
# 	x, y, w, h :  3363.4 6619.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re528
# 	label: no label
# 	x, y, w, h :  4304.1 6680.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re529
# 	label: no label
# 	x, y, w, h :  4359.8 5820.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re530
# 	label: no label
# 	x, y, w, h :  4168.4 5821.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re531
# 	label: no label
# 	x, y, w, h :  4006.3 5824.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re532
# 	label: no label
# 	x, y, w, h :  4206.3 5821.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re533
# 	label: no label
# 	x, y, w, h :  4127.1 5881.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re534
# 	label: no label
# 	x, y, w, h :  3833.4 5824.6 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re536
# 	label: no label
# 	x, y, w, h :  4157.8 8735.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re537
# 	label: no label
# 	x, y, w, h :  4197.7 8679.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re538
# 	label: no label
# 	x, y, w, h :  4328.7 8677.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re539
# 	label: no label
# 	x, y, w, h :  4073.4 8680.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re540
# 	label: no label
# 	x, y, w, h :  3140.0 8417.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re542
# 	label: no label
# 	x, y, w, h :  2417.5 8043.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re543
# 	label: no label
# 	x, y, w, h :  2417.5 8081.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re545
# 	label: no label
# 	x, y, w, h :  2262.5 8048.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re546
# 	label: no label
# 	x, y, w, h :  3056.8 8410.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re547
# 	label: no label
# 	x, y, w, h :  3275.6 8400.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re548
# 	label: no label
# 	x, y, w, h :  2857.4 8469.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re549
# 	label: no label
# 	x, y, w, h :  2876.9 8406.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re550
# 	label: no label
# 	x, y, w, h :  2764.6 8469.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re551
# 	label: no label
# 	x, y, w, h :  2790.0 8418.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re552
# 	label: no label
# 	x, y, w, h :  2621.2 8239.2 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re553
# 	label: no label
# 	x, y, w, h :  2627.5 8324.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re554
# 	label: no label
# 	x, y, w, h :  2298.8 7618.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re555
# 	label: no label
# 	x, y, w, h :  2593.0 8140.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re556
# 	label: no label
# 	x, y, w, h :  7079.5 8893.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re558
# 	label: no label
# 	x, y, w, h :  3120.1 8477.0 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re559
# 	label: no label
# 	x, y, w, h :  3046.9 8441.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re560
# 	label: no label
# 	x, y, w, h :  3052.3 8406.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re561
# 	label: no label
# 	x, y, w, h :  3254.5 8410.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re562
# 	label: no label
# 	x, y, w, h :  5464.7 8753.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re563
# 	label: no label
# 	x, y, w, h :  5490.8 7704.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re564
# 	label: no label
# 	x, y, w, h :  7374.3 8729.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re565
# 	label: no label
# 	x, y, w, h :  9467.7 7753.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re566
# 	label: no label
# 	x, y, w, h :  5969.6 7165.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re567
# 	label: no label
# 	x, y, w, h :  2253.4 6839.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re568
# 	label: no label
# 	x, y, w, h :  3824.5 6732.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re569
# 	label: no label
# 	x, y, w, h :  1238.0 6874.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re570
# 	label: no label
# 	x, y, w, h :  1294.0 6950.1 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re571
# 	label: no label
# 	x, y, w, h :  1471.9 6923.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re572
# 	label: no label
# 	x, y, w, h :  176.5 6958.7 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re574
# 	label: no label
# 	x, y, w, h :  677.4 6807.9 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re575
# 	label: no label
# 	x, y, w, h :  754.1 6900.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re576
# 	label: no label
# 	x, y, w, h :  900.6 6864.4 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re577
# 	label: no label
# 	x, y, w, h :  3008.8 6603.8 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re578
# 	label: no label
# 	x, y, w, h :  5660.3 6799.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re579
# 	label: no label
# 	x, y, w, h :  10093.5 6811.5 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re580
# 	label: no label
# 	x, y, w, h :  2751.8 6846.3 10.0 10.0
#
#
# GlyphClass.PROCESS
# 	id:  pnd_re581
# 	label: no label
# ...
# GlyphClass.COMPLEX
# 	id:  d_csa36
# 	label:  MDC1:RNF8
# 	x, y, w, h :  7142.0 6775.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa260
# 	label:  ATR:ATRIP:CHEK1:CLSPN:RPA1:RPA2:RPA3:TIM1*:TIPIN
# 	x, y, w, h :  5347.0 4274.0 335.0 160.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa45
# 	label:  BRCA1:BRCA2:FANCD2:FANCI:H2AFX:NBS1*:PCNA:RAD51:TIP60*
# 	x, y, w, h :  7018.0 7793.0 362.0 160.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa215
# 	label:  Ku70*:Ku80*:Securin*
# 	x, y, w, h :  5662.0 7175.0 117.0 155.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa40
# 	label:  LIG1:PARP1:PCNA
# 	x, y, w, h :  3171.0 8209.0 106.0 149.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa33
# 	label:  ATM:MRE11*:NBS1*:RAD50
# 	x, y, w, h :  7043.0 6174.0 187.0 117.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa60
# 	label:  CUL1:RBX1:SKP1:SKP2:_beta_TRCP*
# 	x, y, w, h :  3305.0 1038.0 168.0 163.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa91
# 	label:  CTIP*:PCNA
# 	x, y, w, h :  5170.0 4085.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa61
# 	label:  BRCA1:BRCA2:FANCD2:FANCI:H2AFX:NBS1*:PCNA:RAD51:TIP60*
# 	x, y, w, h :  7060.0 8019.0 287.0 180.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa47
# 	label:  MRE11*:NBS1*:RAD50
# 	x, y, w, h :  7386.0 6173.0 95.0 146.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa46
# 	label:  BRCA1:CTIP*
# 	x, y, w, h :  7368.0 6326.0 100.0 135.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa50
# 	label:  RPA1:RPA2:RPA3:SMARCAL1
# 	x, y, w, h :  7152.0 7356.0 146.0 200.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa49
# 	label:  LIG3:WRN
# 	x, y, w, h :  6459.0 8199.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa81
# 	label:  BRCA2:FANCC:FANCG:XRCC3
# 	x, y, w, h :  7030.0 6514.0 200.0 109.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa38
# 	label:  BRCA1:BRCA2:FANCD2:FANCI:FANCJ*:FANCN*:RPA1:RPA2:RPA3
# 	x, y, w, h :  7082.0 8210.0 295.0 161.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa22
# 	label:  RPA1:RPA2:RPA3
# 	x, y, w, h :  7415.0 7451.0 113.0 146.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa56
# 	label:  SMC5:SMC6
# 	x, y, w, h :  7121.0 5900.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa58
# 	label:  EME1:MUS81:SNM1B*
# 	x, y, w, h :  7234.0 8941.0 123.0 166.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa57
# 	label:  BLM:RMI1:TOP3A
# 	x, y, w, h :  7246.0 8771.0 111.0 149.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa53
# 	label:  RAD51:XRCC2:XRCC3
# 	x, y, w, h :  7622.0 7864.0 118.0 170.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa44
# 	label:  CTBP*:CTIP*:RB1
# 	x, y, w, h :  4482.0 4034.0 106.0 171.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa54
# 	label:  BRCA2:DSS1*
# 	x, y, w, h :  7628.0 7631.0 96.0 111.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa62
# 	label:  FEN1:PCNA:WRN
# 	x, y, w, h :  3160.0 7901.0 126.0 178.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa63
# 	label:  EME1:MSH2:MSH3:MUS81:SNM1B*
# 	x, y, w, h :  8598.0 7433.0 198.0 165.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa65
# 	label:  FAAP100*:FANCB:FANCL
# 	x, y, w, h :  9022.0 8281.0 134.0 151.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa89
# 	label:  FANCD2:FANCI:POLN
# 	x, y, w, h :  8680.0 7969.0 125.0 160.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa70
# 	label:  RAD18:RAD6*
# 	x, y, w, h :  9754.0 7018.0 102.0 125.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa67
# 	label:  FANCA:FANCG
# 	x, y, w, h :  9052.0 8452.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa68
# 	label:  ATR:FANCD2:MRE11*:NBS1*:RAD50
# 	x, y, w, h :  5451.0 4688.0 200.0 178.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa64
# 	label:  FANCC:FANCE:FANCF
# 	x, y, w, h :  9032.0 8111.0 127.0 151.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa76
# 	label:  RAD5*:UBC12*:UBE2N
# 	x, y, w, h :  10111.0 7263.0 109.0 157.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa66
# 	label:  FAAP24*:FANCM
# 	x, y, w, h :  8633.0 6872.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa72
# 	label:  PCNA:POLZ*
# 	x, y, w, h :  9605.0 7540.0 100.0 114.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa75
# 	label:  PCNA:POLI:REV1
# 	x, y, w, h :  10020.0 7505.0 100.0 169.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa93
# 	label:  POLH:RAD18:RAD6*:REV1
# 	x, y, w, h :  9515.0 7071.0 192.0 117.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa77
# 	label:  UAF1*:USP1
# 	x, y, w, h :  9270.0 7781.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa73
# 	label:  PCNA:POLK:REV1
# 	x, y, w, h :  9607.0 7200.0 108.0 153.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa74
# 	label:  PCNA:POLH:REV1
# 	x, y, w, h :  9603.0 7363.0 103.0 160.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa249
# 	label:  ATR:ATRIP:CLSPN:RPA1:RPA2:RPA3
# 	x, y, w, h :  5564.0 3893.0 191.0 161.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa52
# 	label:  BLM:EXO1
# 	x, y, w, h :  7138.0 6641.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa82
# 	label:  BRCA1:FANCJ*
# 	x, y, w, h :  7159.0 7229.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa16
# 	label:  MLH1:MLH3
# 	x, y, w, h :  4386.0 7275.0 114.0 118.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa84
# 	label:  FANCJ*:MLH1:PMS2
# 	x, y, w, h :  8674.0 7611.0 122.0 155.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa85
# 	label:  hMutS*
# 	x, y, w, h :  4222.0 7290.0 95.0 71.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa86
# 	label:  PARP1:PNK*:POLB:WRN:XRCC1
# 	x, y, w, h :  2052.0 8140.0 203.0 184.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa87
# 	label:  ATM:SNM1B*
# 	x, y, w, h :  5171.0 4283.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa37
# 	label:  BRCA1:BRCA2:FANCD2:FANCI:FANCJ*:FANCN*:RPA1:RPA2:RPA3
# 	x, y, w, h :  7470.0 8076.0 276.0 161.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa69
# 	label:  FANCD2:FANCI
# 	x, y, w, h :  8916.838 7867.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa90
# 	label:  HEL308*:POLQ
# 	x, y, w, h :  8699.0 7846.0 94.0 109.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa123
# 	label:  ATR:ATRIP:CLSPN:RAD17:TOPBP1
# 	x, y, w, h :  5577.0 3587.0 112.0 236.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa92
# 	label:  H2AFX:MDC1
# 	x, y, w, h :  7132.5 6912.0 95.0 116.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa244
# 	label:  SCC1*:SMC1*:SMC3:STAG*
# 	x, y, w, h :  5331.0 4879.0 184.0 139.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa98
# 	label:  MSH2:MSH3:SLX4*
# 	x, y, w, h :  4881.0 7561.0 122.0 166.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa95
# 	label:  EME1:MUS81:SLX4*
# 	x, y, w, h :  4892.0 8063.0 119.0 162.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa96
# 	label:  SLX1*:SLX4*
# 	x, y, w, h :  4911.0 7767.0 100.0 116.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa97
# 	label:  ERCC1:SLX4*:XPF*
# 	x, y, w, h :  4890.0 7896.0 121.0 157.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa83
# 	label:  hMutL*
# 	x, y, w, h :  4230.5 7372.0 93.0 66.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa99
# 	label:  GADD45A:PCNA
# 	x, y, w, h :  1186.0 7168.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa240
# 	label:  BRCA1:SMC1*
# 	x, y, w, h :  6779.0 980.0 113.0 121.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa233
# 	label:  AURKA:BRCA1
# 	x, y, w, h :  8216.0 7521.0 113.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa197
# 	label:  ORC1*:ORC2*:ORC3*:ORC4*:ORC5*:ORC6*
# 	x, y, w, h :  5437.0 935.0 183.0 153.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa103
# 	label:  CDK4_6*:CIP1_KIP1*:CyclinD*
# 	x, y, w, h :  4413.0 1041.0 118.0 150.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa102
# 	label:  CDK2:CIP1_KIP1*:CyclinE*
# 	x, y, w, h :  4398.0 483.0 119.0 149.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa108
# 	label:  CDK2:CyclinE*:p107*
# 	x, y, w, h :  3785.0 632.0 109.0 152.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa116
# 	label:  CDK2:CyclinA1*:p107*
# 	x, y, w, h :  5295.0 650.0 108.0 152.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa104
# 	label:  CDK4_6*:INK4*
# 	x, y, w, h :  3833.0 911.0 105.0 106.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa112
# 	label:  APC1*:APC10*:APC11*:APC12*:APC2*:APC3*:APC4*:APC5*:APC6*:APC7*:APC8*:CDC20
# 	x, y, w, h :  3780.0 1512.0 278.0 214.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa114
# 	label:  APC1*:APC10*:APC11*:APC12*:APC2*:APC3*:APC4*:APC5*:APC6*:APC7*:APC8*:CDC20:CyclinA1*
# 	x, y, w, h :  4201.0 1513.0 278.0 215.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa195
# 	label:  CDK1:CyclinA1*
# 	x, y, w, h :  5785.0 1541.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa111
# 	label:  APC1*:APC10*:APC11*:APC12*:APC2*:APC3*:APC4*:APC5*:APC6*:APC7*:APC8*:E-Cadherin*
# 	x, y, w, h :  3789.0 1963.0 267.0 240.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa113
# 	label:  APC1*:APC10*:APC11*:APC12*:APC2*:APC3*:APC4*:APC5*:APC6*:APC7*:APC8*:E-Cadherin*
# 	x, y, w, h :  4228.0 1965.0 259.0 238.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa207
# 	label:  APC1*/APC2*/APC3*/APC4*/APC5*/APC6*/APC7*/APC8*/APC9*/APC10*/APC11*/APC12/BUB1/BUB3/BUBR1*/CDC20/MAD1/MAD2
# 	x, y, w, h :  4305.0 4932.0 285.0 338.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa124
# 	label:  CDK4_6*:CyclinD*
# 	x, y, w, h :  3836.0 1209.0 100.0 111.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa106
# 	label:  CDK2:CIP1_KIP1*:CyclinA1*
# 	x, y, w, h :  5434.0 650.0 102.0 152.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa117
# 	label:  CDK2:CyclinE*
# 	x, y, w, h :  3935.25 483.0 97.0 106.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa198
# 	label:  MCM2:MCM3:MCM4:MCM5:MCM6:MCM7
# 	x, y, w, h :  5437.0 1232.0 182.0 156.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa126
# 	label:  CDK4_6*:CyclinD*
# 	x, y, w, h :  3836.0 1041.0 100.0 111.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa205
# 	label:  CDK1:CyclinB1*
# 	x, y, w, h :  5940.0 2321.0 104.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa121
# 	label:  CDK2:CyclinE*
# 	x, y, w, h :  3791.0 483.0 97.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa130
# 	label:  CDK2:CyclinE*
# 	x, y, w, h :  4237.75 483.0 97.0 110.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa105
# 	label:  E2F1:RB1
# 	x, y, w, h :  4829.0 1327.0 105.0 115.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa120
# 	label:  CDK1:CyclinB1*
# 	x, y, w, h :  5493.0 2153.0 104.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa119
# 	label:  CDK7:CyclinH*:MNAT1
# 	x, y, w, h :  4654.875 804.0 96.0 147.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa256
# 	label:  GINS1:GINS2:GINS3:GINS4
# 	x, y, w, h :  6441.0 980.0 176.0 114.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa127
# 	label:  CDK4_6*:CyclinD*
# 	x, y, w, h :  3970.0 1041.0 99.0 107.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa259
# 	label:  TIM1*:TIPIN
# 	x, y, w, h :  5966.0 829.0 97.0 115.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa133
# 	label:  CDK2:CyclinA1*
# 	x, y, w, h :  5596.0 469.0 95.0 106.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa132
# 	label:  CDK2:CyclinA1*
# 	x, y, w, h :  5444.0 469.0 93.0 108.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa122
# 	label:  CDK2:CyclinA1*
# 	x, y, w, h :  5299.0 469.0 94.0 106.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa131
# 	label:  CDK2:CyclinE*
# 	x, y, w, h :  4088.5 483.0 93.0 108.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa134
# 	label:  CDK2:CyclinA1*
# 	x, y, w, h :  5758.0 469.0 95.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa12
# 	label:  CHTF18:PCNA:POLD*:POLE*:POLK:RFC*:RPA1:RPA2:RPA3:XRCC1
# 	x, y, w, h :  794.0 8029.0 332.0 210.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa43
# 	label:  CTBP*:CTIP*
# 	x, y, w, h :  6400.0 7071.0 105.0 123.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa88
# 	label:  HEL308*:POLN
# 	x, y, w, h :  7080.0 8391.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa193
# 	label:  CDK1:CyclinA1*
# 	x, y, w, h :  5482.3335 1539.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa190
# 	label:  CDK1:CyclinA1*
# 	x, y, w, h :  5331.0 1537.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa194
# 	label:  CDK1:CyclinA1*
# 	x, y, w, h :  5633.6665 1537.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa204
# 	label:  CDK1:CyclinA1*
# 	x, y, w, h :  5785.0 1727.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa118
# 	label:  E2F4_5*:p107*
# 	x, y, w, h :  4659.875 983.0 90.0 110.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa129
# 	label:  CDK4_6*:CyclinD*
# 	x, y, w, h :  4260.0 1041.0 99.0 107.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa107
# 	label:  E2F1:RB1
# 	x, y, w, h :  5041.0 1326.0 95.0 113.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa109
# 	label:  CDK1:CyclinB1*
# 	x, y, w, h :  5643.0 2155.0 108.0 104.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa59
# 	label:  BARD1:BRCA1
# 	x, y, w, h :  7632.0 7753.0 93.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa1
# 	label:  LIG3:PARP1:XRCC1
# 	x, y, w, h :  2087.0 8335.0 112.0 167.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa208
# 	label:  APC1*:APC10*:APC11*:APC12*:APC2*:APC3*:APC4*:APC5*:APC6*:APC7*:APC8*
# 	x, y, w, h :  3368.0 1522.0 259.0 197.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa39
# 	label:  Ku70*:Ku80*
# 	x, y, w, h :  5672.0 7057.0 105.0 103.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa216
# 	label:  AURKB:BIRC5:Borealin*:INCENP
# 	x, y, w, h :  4008.0 5193.0 191.0 115.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa101
# 	label:  ATR:ATRIP
# 	x, y, w, h :  5064.0 3157.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa258
# 	label:  ATR:ATRIP:CHEK1:CLSPN:PCNA:TIM1*
# 	x, y, w, h :  5892.0 4700.0 272.0 118.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa222
# 	label:  MIZ1*:MYC:PKMYT1
# 	x, y, w, h :  4620.5 2747.5 100.0 145.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa220
# 	label:  MAX:MYC
# 	x, y, w, h :  4603.5 2598.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa223
# 	label:  MYC:p107*
# 	x, y, w, h :  4653.875 1115.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa125
# 	label:  CDK1:CyclinB1*
# 	x, y, w, h :  5789.0 2152.0 104.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa219
# 	label:  YAP1:p73*
# 	x, y, w, h :  5468.0 5387.0 102.0 124.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa226
# 	label:  14-3-3*:CDC25B
# 	x, y, w, h :  5110.0 1863.0 101.0 126.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa247
# 	label:  HUS1:RAD1:RAD17:RAD9*:RFC*
# 	x, y, w, h :  5446.0 4511.0 195.0 161.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa232
# 	label:  BRCA1:E2F1:RB1
# 	x, y, w, h :  4490.0 4420.0 110.0 156.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa78
# 	label:  ATR:FAAP24*:FANCM:HCLK2*
# 	x, y, w, h :  5756.0 4275.0 183.0 132.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa239
# 	label:  SCC1*:SMC1*:SMC3:STAG*
# 	x, y, w, h :  5606.0 4886.0 176.0 118.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa203
# 	label:  CDC7:DBF4
# 	x, y, w, h :  5980.0 1234.0 93.0 111.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa253
# 	label:  ATR:ATRIP:CHEK1:CLSPN:HCLK2*
# 	x, y, w, h :  5747.0 4463.0 193.0 161.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa110
# 	label:  CDK1:CyclinB1*
# 	x, y, w, h :  5935.0 2153.0 104.0 105.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa18
# 	label:  MSH2:MSH3
# 	x, y, w, h :  4385.0 7156.0 110.0 113.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa48
# 	label:  XAB2:XPA
# 	x, y, w, h :  928.0 7168.0 98.0 112.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa229
# 	label:  PARP1:p53*
# 	x, y, w, h :  4486.0 4257.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa266
# 	label:  BRIT1*:E2F1
# 	x, y, w, h :  6451.0 2601.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa241
# 	label:  BRCA1:SMC3
# 	x, y, w, h :  6645.0 980.0 105.0 124.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa242
# 	label:  SMC1*:SMC3
# 	x, y, w, h :  7125.0 6041.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa228
# 	label:  H2AFX:PARP1
# 	x, y, w, h :  4495.0 4590.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa245
# 	label:  HUS1:RAD1:RAD9*
# 	x, y, w, h :  3194.0 7473.0 104.0 173.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa71
# 	label:  PCNA:REV1
# 	x, y, w, h :  9597.0 6938.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa100
# 	label:  CDK1:CyclinB1*:GADD45A
# 	x, y, w, h :  4999.5 5201.0 141.0 158.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa218
# 	label:  Securin*:Separin*
# 	x, y, w, h :  3032.0 2123.0 100.0 113.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa230
# 	label:  CIP1_KIP1*:PARP1
# 	x, y, w, h :  4652.875 477.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa250
# 	label:  PPP5C:RAD17
# 	x, y, w, h :  6203.0 3601.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa128
# 	label:  CDK4_6*:CyclinD*
# 	x, y, w, h :  4113.0 1041.0 99.0 107.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa225
# 	label:  14-3-3*:CDK1:CyclinB1*
# 	x, y, w, h :  6122.0 2131.0 143.0 150.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa115
# 	label:  E2F4_5*:p107*
# 	x, y, w, h :  4827.0 973.0 93.0 110.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa263
# 	label:  HUS1:MUTH*:RAD1:RAD9*
# 	x, y, w, h :  2027.0 7464.0 176.0 108.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa25
# 	label:  APE*:Mg2+:PCNA:WRN
# 	x, y, w, h :  2063.0 7685.0 140.0 210.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa28
# 	label:  NTH1*:XPG*
# 	x, y, w, h :  2026.0 7015.0 166.0 79.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa264
# 	label:  HUS1:RAD1:RAD9*:TDG
# 	x, y, w, h :  3122.0 7344.0 178.0 114.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa265
# 	label:  LIG3:XRCC1
# 	x, y, w, h :  1023.0 8279.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa227
# 	label:  14-3-3*:CDC25C
# 	x, y, w, h :  5425.0 1866.0 96.0 128.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa267
# 	label:  LIG4:PNK*:XRCC4
# 	x, y, w, h :  5694.0 7459.0 107.0 158.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa268
# 	label:  MCM8*:MCM9*
# 	x, y, w, h :  7466.0 8264.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa269
# 	label:  PARP2:PNK*:POLB:WRN:XRCC1
# 	x, y, w, h :  2051.305 7952.1816 203.0 184.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa271
# 	label:  PARP1:PARP3
# 	x, y, w, h :  2689.0 8345.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa270
# 	label:  PARP1:PARP2
# 	x, y, w, h :  2686.0 8204.0 100.0 120.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa272
# 	label:  CDK5:EME1:STAT3
# 	x, y, w, h :  7033.0 8935.0 111.0 160.0
#
#
# GlyphClass.COMPLEX
# 	id:  d_csa273
# 	label:  DNA-PK*:Ku70*:Ku80*:WRN
# 	x, y, w, h :  5911.0 7199.0 192.0 120.0

# %%
arcs = smap.get_arc()
for a in arcs:
    cls, source, target, id_ = a.get_class(), a.get_source(), a.get_target(), a.get_id()
    print("class: {}\n\tid: {}\n\tsource: {}\n\ttarget: {}"
          .format(cls, id_, source, target))
    start = a.get_start()
    print("\tstart: {} {}".format(start.x, start.y))
    end = a.get_end()
    print("\tend: {} {}".format(end.x, end.y))
    print("\n")
# Out:
# class: ArcClass.CONSUMPTION
# 	id: d_re1-react0
# 	source: d_sa2
# 	target: pnd_re1.L
# 	start: 2971.565 7246.838
# 	end: 2966.6 7378.6
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re1-product0
# 	source: pnd_re1.R
# 	target: d_sa5
# 	start: 2976.6 7378.6
# 	end: 2971.565 7510.3765
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re1-mod0
# 	source: d_csa25
# 	target: pnd_re1
# 	start: 2133.0 7790.0
# 	end: 2966.555 7378.1074
#
#
# class: ArcClass.MODULATION
# 	id: d_re1-mod1
# 	source: d_csa245
# 	target: pnd_re1
# 	start: 3246.0 7559.5
# 	end: 2976.575 7383.117
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re2-react0
# 	source: d_sa5
# 	target: pnd_re2.R
# 	start: 2971.565 7510.3765
# 	end: 2423.2 7693.0
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re2-product0
# 	source: pnd_re2.L
# 	target: d_sa6
# 	start: 2413.2 7693.0
# 	end: 1864.8738 7875.6055
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re2-addProduct1
# 	source: pnd_re2.L
# 	target: d_sa4
# 	start: 2413.2 7693.0
# 	end: 2338.5 7786.5
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re2-mod0
# 	source: d_sa27
# 	target: pnd_re2
# 	start: 2150.75 7603.0
# 	end: 2415.0317 7699.319
#
#
# class: ArcClass.MODULATION
# 	id: d_re2-mod1
# 	source: d_sa26
# 	target: pnd_re2
# 	start: 2339.5 7676.5
# 	end: 2416.6492 7688.2334
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re3-react0
# 	source: d_sa6
# 	target: pnd_re3.L
# 	start: 1864.8738 7875.6055
# 	end: 1859.9 8046.0
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re3-product0
# 	source: pnd_re3.R
# 	target: d_sa7
# 	start: 1869.9 8046.0
# 	end: 1864.8738 8216.488
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re3-addReact1
# 	source: d_sa48
# 	target: pnd_re3.L
# 	start: 1845.5 8027.0
# 	end: 1859.9 8046.0
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re3-mod0
# 	source: d_csa86
# 	target: pnd_re3
# 	start: 2154.0 8232.0
# 	end: 1869.8838 8045.547
#
#
# class: ArcClass.MODULATION
# 	id: d_re3-mod1
# 	source: d_sa26
# 	target: pnd_re3
# 	start: 2339.5 7676.5
# 	end: 1859.8638 8045.547
#
#
# class: ArcClass.CATALYSIS
# 	id: d_
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re15-addReact2
# 	source: d_csa48
# 	target: pnd_re15.L
# 	start: 928.0 7196.0
# 	end: 770.9 7234.7
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re16-react0
# 	source: d_csa9
# 	target: pnd_re16.R
# 	start: 777.5 7383.0
# 	end: 980.3 7645.2
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re16-product0
# 	source: pnd_re16.L
# 	target: d_csa11
# 	start: 970.3 7645.2
# 	end: 974.5 7690.0
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re16-react1
# 	source: d_sa37
# 	target: pnd_re16.R
# 	start: 1146.5553 7595.068
# 	end: 980.3 7645.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re16-addReact2
# 	source: d_sa36
# 	target: pnd_re16.R
# 	start: 1106.1106 7665.568
# 	end: 980.3 7645.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re16-addReact3
# 	source: d_sa35
# 	target: pnd_re16.R
# 	start: 2301.5 7067.5
# 	end: 980.3 7645.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re17-react0
# 	source: d_sa270
# 	target: pnd_re17.L
# 	start: 722.8866 8292.488
# 	end: 717.9 8371.2
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re17-product0
# 	source: pnd_re17.R
# 	target: d_sa1434
# 	start: 727.9 8371.2
# 	end: 722.8866 8450.0
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re17-mod0
# 	source: d_sa9
# 	target: pnd_re17
# 	start: 4968.75 8255.5
# 	end: 727.8966 8370.744
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re17-mod1
# 	source: d_csa265
# 	target: pnd_re17
# 	start: 1073.0 8339.0
# 	end: 717.8766 8375.754
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re18-react0
# 	source: d_sa43
# 	target: pnd_re18.R
# 	start: 1709.7576 7168.94
# 	end: 535.4 7099.2
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re18-product0
# 	source: pnd_re18.L
# 	target: d_csa14
# 	start: 525.4 7099.2
# 	end: 483.0 7124.945
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re18-react1
# 	source: d_sa44
# 	target: pnd_re18.R
# 	start: 433.51532 6970.812
# 	end: 535.4 7099.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re18-addReact2
# 	source: d_sa45
# 	target: pnd_re18.R
# 	start: 429.51532 7022.684
# 	end: 535.4 7099.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re18-addReact3
# 	source: d_sa46
# 	target: pnd_re18.R
# 	start: 429.51532 7080.5566
# 	end: 535.4 7099.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re19-react0
# 	source: d_sa42
# 	target: pnd_re19.R
# 	start: 1712.7576 7114.0674
# 	end: 1639.6 7158.1
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re19-product0
# 	source: pnd_re19.L
# 	target: d_csa13
# 	start: 1629.6 7158.1
# 	end: 1623.0 7157.2793
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re19-react1
# 	source: d_sa43
# 	target: pnd_re19.R
# 	start: 1709.7576 7168.94
# 	end: 1639.6 7158.1
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re19-addReact2
# 	source: d_sa44
# 	target: pnd_re19.R
# 	start: 434.51532 6951.812
# 	end: 1639.6 7158.1
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re19-addReact3
# 	source: d_sa45
# 	target: pnd_re19.R
# 	start: 430.51532 7003.684
# 	end: 1639.6 7158.1
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re20-react0
# 	source: d_sa7
# 	target: pnd_re20.L
# 	start: 1864.8738 8216.488
# 	end: 1859.9 8323.7
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re20-product0
# 	source: pnd_re20.R
# 	target: d_sa1437
# 	start: 1869.9 8323.7
# 	end: 1864.8738 8430.833
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re20-mod0
# 	source: d_csa1
# 	target: pnd_re20
# 	start: 2143.0 8418.5
# 	end: 1869.8838 8323.16
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re21-react0
# 	source: d_sa8
# 	target: pnd_re21.L
# 	start: 2971.565 8164.4883
# 	end: 2966.6 8289.7
#
#
# class: ArcClass.PRODUCTION
# 	id: d_
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re36-react0
# 	source: d_sa55
# 	target: pnd_re36.R
# 	start: 4707.374 3173.6404
# 	end: 4712.3 3304.3
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re36-product0
# 	source: pnd_re36.L
# 	target: d_sa63
# 	start: 4702.3 3304.3
# 	end: 4707.249 3434.9626
#
#
# class: ArcClass.STIMULATION
# 	id: d_re36-mod0
# 	source: d_csa19
# 	target: pnd_re36
# 	start: 4023.25 7246.0
# 	end: 4873.083 5255.053
#
#
# class: ArcClass.STIMULATION
# 	id: d_re36-mod1
# 	source: d_csa20
# 	target: pnd_re36
# 	start: 4029.0 7123.5
# 	end: 4873.083 5255.053
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod2
# 	source: d_sa119
# 	target: pnd_re36
# 	start: 5525.204 7046.488
# 	end: 4715.7773 3303.6995
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod3
# 	source: d_sa1612
# 	target: pnd_re36
# 	start: 6319.157 6980.5
# 	end: 4715.816 3298.6897
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod4
# 	source: d_sa152
# 	target: pnd_re36
# 	start: 6858.0635 5851.3
# 	end: 4705.7964 3298.613
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod5
# 	source: d_csa47
# 	target: pnd_re36
# 	start: 7433.5 6246.0
# 	end: 4705.7197 3308.6326
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re36-mod6
# 	source: d_sa55
# 	target: pnd_re36
# 	start: 4707.374 3173.6404
# 	end: 4715.816 3298.6897
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod7
# 	source: d_csa34
# 	target: pnd_re36
# 	start: 6032.0 4906.5
# 	end: 4705.7964 3298.613
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod8
# 	source: d_sa1317
# 	target: pnd_re36
# 	start: 6015.0 3581.0
# 	end: 4715.816 3298.6897
#
#
# class: ArcClass.MODULATION
# 	id: d_re36-mod9
# 	source: d_sa196
# 	target: pnd_re36
# 	start: 8473.094 6562.786
# 	end: 4705.7964 3298.613
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re36-mod10
# 	source: d_sa1584
# 	target: pnd_re36
# 	start: 2446.0 7576.0
# 	end: 4705.7964 3298.613
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re37-react0
# 	source: d_sa56
# 	target: pnd_re37.R
# 	start: 3996.5 3175.5
# 	end: 4002.6 3308.8
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re37-product0
# 	source: pnd_re37.L
# 	target: d_sa66
# 	start: 3992.6 3308.8
# 	end: 3998.75 3442.168
#
#
# class: ArcClass.STIMULATION
# 	id: d_re37-mod0
# 	source: d_csa19
# 	target: pnd_re37
# 	start: 4023.25 7246.0
# 	end: 4637.9165 5255.945
#
#
# class: ArcClass.STIMULATION
# 	id: d_re37-mod1
# 	source: d_csa20
# 	target: pnd_re37
# 	start: 4029.0 7123.5
# 	end: 4637.9165 5255.945
#
#
# class: ArcClass.STIMULATION
# 	id: d_re37-mod2
# 	source: d_sa196
# 	target: pnd_re37
# 	start: 8473.094 6562.786
# 	end: 4006.1326 3306.3293
#
#
# class: ArcClass.MODULATION
# 	id: d_re37-mod3
# 	source: d_sa19
# 	target: pnd_re37
# 	start: 1880.8738 6948.3
# 	end: 3996.108 3301.3286
#
#
# class: ArcClass.MODULATION
# 	id: d_re37-mod4
# 	source: d_sa1
# 	target: pnd_re37
# 	start: 2969.565 6946.8
# 	end: 4006.1326 3306.3293
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re73-mod2
# 	source: d_csa34
# 	target: pnd_re73
# 	start: 6032.0 4906.5
# 	end: 5892.4863 3301.1487
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re74-react0
# 	source: d_sa109
# 	target: pnd_re74.L
# 	start: 7596.115 6722.767
# 	end: 7643.8 6720.6
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re74-product0
# 	source: pnd_re74.R
# 	target: d_sa113
# 	start: 7653.8 6720.6
# 	end: 7701.5 6718.5
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re75-react0
# 	source: d_sa390
# 	target: pnd_re75.R
# 	start: 2295.8044 7328.253
# 	end: 2210.4 7294.6
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re75-product0
# 	source: pnd_re75.L
# 	target: d_csa24
# 	start: 2200.4 7294.6
# 	end: 2191.0 7292.1084
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re75-react1
# 	source: d_sa114
# 	target: pnd_re75.R
# 	start: 2334.7712 7251.567
# 	end: 2210.4 7294.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re75-addReact2
# 	source: d_sa68
# 	target: pnd_re75.R
# 	start: 2301.9653 7384.6475
# 	end: 2210.4 7294.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re76-react0
# 	source: d_sa115
# 	target: pnd_re76.R
# 	start: 2304.5425 7432.567
# 	end: 2236.6 7414.8
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re76-product0
# 	source: pnd_re76.L
# 	target: d_csa5
# 	start: 2226.6 7414.8
# 	end: 2200.0 7409.833
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re76-react1
# 	source: d_csa5
# 	target: pnd_re76.R
# 	start: 2116.0 7395.0
# 	end: 2236.6 7414.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re76-addReact2
# 	source: d_sa68
# 	target: pnd_re76.R
# 	start: 2301.9653 7384.6475
# 	end: 2236.6 7414.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re76-addReact3
# 	source: d_sa390
# 	target: pnd_re76.R
# 	start: 2294.8044 7319.253
# 	end: 2236.6 7414.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re77-react0
# 	source: d_sa116
# 	target: pnd_re77.R
# 	start: 3420.288 7302.567
# 	end: 3335.4 7252.8
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re77-product0
# 	source: pnd_re77.L
# 	target: d_csa26
# 	start: 3325.4 7252.8
# 	end: 3300.0 7253.6777
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re77-react1
# 	source: d_sa31
# 	target: pnd_re77.R
# 	start: 3424.788 7243.5
# 	end: 3335.4 7252.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re77-addReact2
# 	source: d_sa32
# 	target: pnd_re77.R
# 	start: 3383.5762 7192.5
# 	end: 3335.4 7252.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re78-react0
# 	source: d_sa118
# 	target: pnd_re78.R
# 	start: 2341.543 7020.606
# 	end: 2234.1 7055.2
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re78-product0
# 	source: pnd_re78.L
# 	target: d_csa28
# 	start: 2224.1 7055.2
# 	end: 2192.0 7055.0244
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re78-react1
# 	source: d_sa35
# 	target: pnd_re78.R
# 	start: 2341.75 7067.5
# 	end: 2234.1 7055.2
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re79-react0
# 	source: d_sa120
# 	target: pnd_re79.R
# 	start: 5892.75 7077.9077
# 	end: 5796.3 7121.9
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re79-product0
# 	source: pnd_re79.L
# 	target: d_csa39
# 	start: 5786.3 7121.9
# 	end: 5777.0 7119.592
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re79-react1
# 	source: d_sa121
# 	target: pnd_re79.R
# 	start: 5889.0 7132.5
# 	end: 5796.3 7121.9
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re79-mod0
# 	source: d_csa34
# 	target: pnd_re79
# 	start: 6032.0 4906.5
# 	end: 5786.31 7126.7266
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re80-react0
# 	source: d_sa119
# 	target: pnd_re80.R
# 	start: 5525.204 7046.488
# 	end: 5530.2 7165.6
#
#
# class: ArcClass.PRODUCTION
# 	id: d_
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re85-addReact2
# 	source: d_sa1581
# 	target: pnd_re85.R
# 	start: 6030.857 8130.7144
# 	end: 5924.3 8221.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re85-addReact3
# 	source: d_sa125
# 	target: pnd_re85.R
# 	start: 6022.0 7835.9077
# 	end: 5924.3 8221.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re85-addReact4
# 	source: d_sa1597
# 	target: pnd_re85.R
# 	start: 5948.3237 8064.4414
# 	end: 5924.3 8221.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re85-addReact5
# 	source: d_sa1596
# 	target: pnd_re85.R
# 	start: 5919.3237 8085.4414
# 	end: 5924.3 8221.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re85-addReact6
# 	source: d_sa1599
# 	target: pnd_re85.R
# 	start: 5960.0 8351.0
# 	end: 5924.3 8221.6
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re86-react0
# 	source: d_sa129
# 	target: pnd_re86.R
# 	start: 6168.769 8280.908
# 	end: 6087.8 8218.3
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re86-product0
# 	source: pnd_re86.L
# 	target: d_csa32
# 	start: 6077.8 8218.3
# 	end: 6048.0 8220.987
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re86-react1
# 	source: d_sa126
# 	target: pnd_re86.R
# 	start: 6168.769 8222.908
# 	end: 6087.8 8218.3
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re86-addReact2
# 	source: d_sa127
# 	target: pnd_re86.R
# 	start: 6128.5376 8163.9077
# 	end: 6087.8 8218.3
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re90-react0
# 	source: d_sa131
# 	target: pnd_re90.R
# 	start: 6352.5 2794.913
# 	end: 6356.4 2706.2
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re90-product0
# 	source: pnd_re90.L
# 	target: d_sa132
# 	start: 6346.4 2706.2
# 	end: 6350.25 2617.5054
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re90-mod0
# 	source: d_csa33
# 	target: pnd_re90
# 	start: 7137.0 6232.5
# 	end: 6360.823 2713.6428
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re90-mod1
# 	source: d_sa66
# 	target: pnd_re90
# 	start: 3998.75 3442.168
# 	end: 6360.7524 2708.6333
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re90-mod2
# 	source: d_sa124
# 	target: pnd_re90
# 	start: 6136.126 7853.9077
# 	end: 6360.6816 2703.6238
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re91-react0
# 	source: d_sa133
# 	target: pnd_re91.R
# 	start: 7587.9595 6286.9077
# 	end: 7540.0 6247.8
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re91-product0
# 	source: pnd_re91.L
# 	target: d_csa47
# 	start: 7530.0 6247.8
# 	end: 7481.0 6246.898
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re91-react1
# 	source: d_sa134
# 	target: pnd_re91.R
# 	start: 7587.9595 6338.9077
# 	end: 7540.0 6247.8
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re91-addReact2
# 	source: d_sa135
# 	target: pnd_re91.R
# 	start: 7552.419 6208.9077
# 	end: 7540.0 6247.8
#
#
# class: ArcClass.MODULATION
# 	id: d_re91-mod0
# 	source: d_sa119
# 	target: pnd_re91
# 	start: 5525.204 7046.488
# 	end: 7540.229 6243.007
#
#
# class: ArcClass.MODULATION
# 	id: d_re91-mod1
# 	source: d_sa1612
# 	target: pnd_re91
# 	start: 6319.157 6993.5
# 	end: 7535.2197 6242.912
#
#
# class: ArcClass.MODULATION
# 	id: d_re91-mod2
# 	source: d_sa152
# 	target: pnd_re91
# 	start: 6858.0635 5851.3
# 	end: 7540.0396 6253.025
#
#
# class: ArcClass.MODULATION
# 	id: d_re91-mod3
# 	source: d_sa196
# 	target: pnd_re91
# 	start: 8473.094 6562.786
# 	end: 7530.2104 6242.8174
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re603-product0
# 	source: pnd_re603.R
# 	target: d_sa317
# 	start: 4671.6 731.9
# 	end: 4710.25 718.875
#
#
# class: ArcClass.CATALYSIS
# 	id: d_re603-mod0
# 	source: d_sa64
# 	target: pnd_re603
# 	start: 5488.0 3422.168
# 	end: 4665.188 727.13806
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re604-react0
# 	source: d_sa1496
# 	target: pnd_re604.R
# 	start: 4910.25 6328.5
# 	end: 3047.6 6521.0
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re604-product0
# 	source: pnd_re604.L
# 	target: d_sa1618
# 	start: 3037.6 6521.0
# 	end: 1175.0 6713.5
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re605-react0
# 	source: d_sa1496
# 	target: pnd_re605.R
# 	start: 4747.5 6309.75
# 	end: 4711.1 6512.6
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re605-product0
# 	source: pnd_re605.L
# 	target: d_sa1613
# 	start: 4701.1 6512.6
# 	end: 4664.75 6715.5
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re606-react0
# 	source: d_sa1496
# 	target: pnd_re606.R
# 	start: 4801.75 6303.5
# 	end: 3078.9 6592.0
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re606-product0
# 	source: pnd_re606.L
# 	target: d_sa1616
# 	start: 3068.9 6592.0
# 	end: 1346.0 6880.5
#
#
# class: ArcClass.CONSUMPTION
# 	id: d_re607-react0
# 	source: d_sa1496
# 	target: pnd_re607.R
# 	start: 4801.75 6328.5
# 	end: 3197.1 6578.0
#
#
# class: ArcClass.PRODUCTION
# 	id: d_re607-product0
# 	source: pnd_re607.L
# 	target: d_sa1617
# 	start: 3187.1 6578.0
# 	end: 1582.5 6827.5

# %%
print("# arcs: ", len(arcs))
print("# glyphs: ", len(glyphs))
# Out:
# # arcs:  2064
# # glyphs:  2004

# %%
for i, glyph in enumerate(glyphs_with_glyphs):
    sub_glyphs = glyph.get_glyph()
    for j, g in enumerate(sub_glyphs):
        print_glyph(g)
        id_ = g.get_id()
        if 'd_s2072_d_sa748' == id_:
            index = (i, j)

# %%
index

# %%
g = glyphs_with_glyphs[101]

# %%
print_glyph(g)

# %%
sg = g.get_glyph()

# %%
len(sg)

# %%
[print_glyph(gi) for gi in sg]

# %%
print_glyph(glyph)
# Out:
# GlyphClass.COMPLEX
# 	id:  d_csa273
# 	label:  DNA-PK*:Ku70*:Ku80*:WRN
# 	x, y, w, h :  5911.0 7199.0 192.0 120.0

# %%
glyph.export("~/temp/a.txt", level=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-56b115c845b8> in <module>()
# ----> 1 glyph.export("~/temp/a.txt", level=1)
#
# ~/.virtualenvs/bioconverter/lib/python3.5/site-packages/libsbgnpy/libsbgn.py in export(self, outfile, level, namespace_, name_, namespacedef_, pretty_print)
#    1799         if self.original_tagname_ is not None:
#    1800             name_ = self.original_tagname_
# -> 1801         showIndent(outfile, level, pretty_print)
#    1802         outfile.write('<%s%s%s' % (namespace_, name_, namespacedef_ and ' ' + namespacedef_ or '', ))
#    1803         already_processed = set()
#
# ~/.virtualenvs/bioconverter/lib/python3.5/site-packages/libsbgnpy/libsbgn.py in showIndent(outfile, level, pretty_print)
#     452     if pretty_print:
#     453         for idx in range(level):
# --> 454             outfile.write('    ')
#     455
#     456
#
# AttributeError: 'str' object has no attribute 'write'

# %%
# ?glyph.exportAttributes
